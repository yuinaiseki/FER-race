# %% [markdown]
# <a href="https://colab.research.google.com/github/yuinaiseki/FER-race/blob/main/fer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CS231N Project!** Qualitative Analysis on Racial Bias in SOTA Facial Emotion Recognition models

# %% [markdown]
# **Preparing workspace:** Mounting drive to workspace, installing dependencies
#
# Make sure Runtime is set to GPU (either T4 or A100) - Models below are not designed for CPUs; it'll take an impractically long time to run :)

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount("/content/drive")

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = "cs231n_project/"
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# Installing dependencies
# !pip install transformers accelerate timm grad-cam openai-clip
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install Pillow matplotlib scikit-learn numpy pandas seaborn
# !pip install bitsandbytes
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 17.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.1 MB/s eta 0:00:00
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44286 sha256=43c17f112c12344c02fb14a965270d633a500e8a84abdbbca7376c52094697dd
#   Stored in directory: /root/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
# ...
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368605 sha256=16cdc3e6158071a9e8e01aa9c0579de5593147e69d155e029e4d4bd2ffc264d4
#   Stored in directory: /root/.cache/pip/wheels/ab/49/bc/c2342e8e14878210ba4825cf314a53f2570f6fb18b91fce3cf
# ...

# %% [markdown]
# **Preprocessing dataset:** maybe? data augmentation/filtering/etc.

# %%
# TO-DO: maybe?

# %% [markdown]
# **Loading dataset:** TO-DO

# %%
# TO-DO: America

# %% [markdown]
# **Grad-CAM:** set up

# %%
# TO-DO: grad cam

# %% [markdown]
# **Zero-shot performance on SOTA VLMs:**
#
# - CLIP ViT-B/32
#   - Two distinct neural networks: a Vision Transformer (ViT) or ResNet for the image encoder and a transformer-based architecture (such as a GPT model) for the text encoder
#   - 400 million parameters
# - Phi-3.5 Vision
#    - Multimodal model with a 4.2-billion-parameter framework. It is designed to reason and comprehend images contextually rather than just extracting pixel-level features
#    - 4.2 billion parameters
# - (maybe) LLaMA-3.2 Vision Instruct
#
#
# Source: https://arxiv.org/abs/2508.13524

# %%
# TO-DO: Yuina

# %% [markdown]
# **Fine-tune SOTA VLMs:**
# - CLIP ViT-B/32
#   - Fine-tune for 30 epochs with a batch size of 64 using a T4 GPU
# - Phi-3.5 Vision
#   - Fine-tune for 30 epochs with a batch size of 32
# - (maybe) LLaMA-3.2 Vision Instruct

# %%
# TO-DO: Yuina

# %% [markdown]
# Grad-CAM comparison of results?
